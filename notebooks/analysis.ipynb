# %% [markdown]
# <a href="https://colab.research.google.com/github/Yassir050/Smart-Student-Predictor/blob/main/notebooks/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Yassir050/Smart-Student-Predictor.git
# %cd Smart-Student-Predictor
# Out:
# Cloning into 'Smart-Student-Predictor'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 48 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 15.12 KiB | 672.00 KiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/Smart-Student-Predictor

# %%
# !pip install -r requirements.txt

# %%
import pandas as pd

df = pd.read_csv("data/students.csv")
df.head()
# Out:
#    study_hours  attendance  previous_score  sleep_hours  final_score
# 0            1          65              48            5           49
# 1            2          70              52            6           54
# 2            3          75              58            6           60
# 3            4          80              63            7           66
# 4            5          85              68            7           72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   study_hours     20 non-null     int64
#  1   attendance      20 non-null     int64
#  2   previous_score  20 non-null     int64
#  3   sleep_hours     20 non-null     int64
#  4   final_score     20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
df.describe()
# Out:
#        study_hours  attendance  previous_score  sleep_hours  final_score
# count    20.000000   20.000000       20.000000    20.000000    20.000000
# mean      5.200000   82.850000       68.250000     7.000000    72.400000
# std       2.764436   10.984559       13.610658     1.256562    15.496689
# min       1.000000   60.000000       45.000000     5.000000    46.000000
# 25%       3.000000   75.750000       58.750000     6.000000    62.250000
# 50%       5.000000   85.500000       69.000000     7.000000    73.000000
# 75%       7.250000   91.250000       78.750000     8.000000    84.750000
# max      10.000000   97.000000       90.000000     9.000000    96.000000

# %%
df.isnull().sum()
# Out:
# study_hours       0
# attendance        0
# previous_score    0
# sleep_hours       0
# final_score       0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                 study_hours  attendance  previous_score  sleep_hours  \
# study_hours        1.000000    0.964718        0.990362     0.954545
# attendance         0.964718    1.000000        0.986663     0.960905
# previous_score     0.990362    0.986663        1.000000     0.969380
# sleep_hours        0.954545    0.960905        0.969380     1.000000
# final_score        0.993178    0.986067        0.998881     0.967624
#
#                 final_score
# study_hours        0.993178
# attendance         0.986067
# previous_score     0.998881
# sleep_hours        0.967624
# final_score        1.000000

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
# !python src/train.py
# Out:
# Training completed.
# MAE: 0.57
# R²: 1.00
# Model saved to: /content/Smart-Student-Predictor/models/student_model.pkl

# %%
# !python src/predict.py
# Out:
# Predicted Score: 80.04
